# %%
### 2. Pandas DataFrame Introduction
#Create a file at **`01_python/01_pandas/dataframe_intro.md`**:

#```markdown
# Pandas: DataFrame Introduction

#Here is how you initialize and display a basic data frame using Pandas:

#```python
import pandas as pd

# Create a sample dictionary containing course data
data = {
    "Course": ["Python Basics", "Pandas Intro", "NumPy Arrays"],
    "Difficulty": ["Beginner", "Intermediate", "Intermediate"],
    "Completed": [True, False, False]
}

# Convert the dictionary into a DataFrame
df = pd.DataFrame(data)

# Display the data frame
print(df)
# Out:
#           Course    Difficulty  Completed
# 0  Python Basics      Beginner       True
# 1   Pandas Intro  Intermediate      False
# 2   NumPy Arrays  Intermediate      False
